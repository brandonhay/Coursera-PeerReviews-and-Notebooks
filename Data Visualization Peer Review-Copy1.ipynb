# %%
import numpy as np
import pandas as pd

# %%
# !conda install -c anaconda xlrd --yes
print('installed')
# Out:
# ...
# Solving environment: done
#
# # All requested packages already installed.
#
# installed

# %%
df = pd.read_csv('Topic_Survey_Assignment.csv', index_col=0)
df
# Out:
#                             Very interested  Somewhat interested  \
# Big Data (Spark / Hadoop)              1332                  729
# Data Analysis / Statistics             1688                  444
# Data Journalism                         429                 1081
# Data Visualization                     1340                  734
# Deep Learning                          1263                  770
# Machine Learning                       1629                  477
#
#                             Not interested
# Big Data (Spark / Hadoop)              127
# Data Analysis / Statistics              60
# Data Journalism                        610
# Data Visualization                     102
# Deep Learning                          136
# Machine Learning                        74

# %%
df.sort_values(by='Very interested', ascending=False, inplace=True)
df
# Out:
#                             Very interested  Somewhat interested  \
# Data Analysis / Statistics             1688                  444
# Machine Learning                       1629                  477
# Data Visualization                     1340                  734
# Big Data (Spark / Hadoop)              1332                  729
# Deep Learning                          1263                  770
# Data Journalism                         429                 1081
#
#                             Not interested
# Data Analysis / Statistics              60
# Machine Learning                        74
# Data Visualization                     102
# Big Data (Spark / Hadoop)              127
# Deep Learning                          136
# Data Journalism                        610

# %%
df['Total'] = df.sum(axis=1)
df
# Out:
#                             Very interested  Somewhat interested  \
# Data Analysis / Statistics             1688                  444
# Machine Learning                       1629                  477
# Data Visualization                     1340                  734
# Big Data (Spark / Hadoop)              1332                  729
# Deep Learning                          1263                  770
# Data Journalism                         429                 1081
#
#                             Not interested   Total
# Data Analysis / Statistics              60  2192.0
# Machine Learning                        74  2180.0
# Data Visualization                     102  2176.0
# Big Data (Spark / Hadoop)              127  2188.0
# Deep Learning                          136  2169.0
# Data Journalism                        610  2120.0

# %%
df.drop('Total', axis=1, inplace=True)
df
# Out:
#                             Very interested  Somewhat interested  \
# Data Analysis / Statistics             1688                  444
# Machine Learning                       1629                  477
# Data Visualization                     1340                  734
# Big Data (Spark / Hadoop)              1332                  729
# Deep Learning                          1263                  770
# Data Journalism                         429                 1081
#
#                             Not interested
# Data Analysis / Statistics              60
# Machine Learning                        74
# Data Visualization                     102
# Big Data (Spark / Hadoop)              127
# Deep Learning                          136
# Data Journalism                        610

# %%
total = 2233
df_pct = (df/total)*100
df_pct[['Very interested', 'Somewhat interested', 'Not interested']].round(decimals=2)
# Out:
#                             Very interested  Somewhat interested  \
# Data Analysis / Statistics            75.59                19.88
# Machine Learning                      72.95                21.36
# Data Visualization                    60.01                32.87
# Big Data (Spark / Hadoop)             59.65                32.65
# Deep Learning                         56.56                34.48
# Data Journalism                       19.21                48.41
#
#                             Not interested
# Data Analysis / Statistics            2.69
# Machine Learning                      3.31
# Data Visualization                    4.57
# Big Data (Spark / Hadoop)             5.69
# Deep Learning                         6.09
# Data Journalism                      27.32

# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
ax = df_pct.plot(kind='bar', figsize=(20,8), width=.8, 
                color=(['#5cb85c', '#5bc0de', '#d9534f']),
                fontsize=14)
ax.set_title('Percentage of Respondents Interest in Data Science Areas', fontsize=16)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.yaxis.set_visible(False)

plt.annotate('75.59', xy=(-.35, 77))
plt.annotate('19.88', xy=(-.1, 21))
plt.annotate('2.69', xy=(.2, 4))
plt.annotate('72.95', xy=(.65, 74))
plt.annotate('21.36', xy=(.9, 23))
plt.annotate('3.31', xy=(1.2, 5))
plt.annotate('60.01', xy=(1.65, 62))
plt.annotate('32.87', xy=(1.9, 34))
plt.annotate('4.57', xy=(2.20, 6))
plt.annotate('59.65', xy=(2.65, 61))
plt.annotate('32.65', xy=(2.9, 34))
plt.annotate('5.69', xy=(3.2, 7))
plt.annotate('56.56', xy=(3.65, 58))
plt.annotate('34.48', xy=(3.9, 36))
plt.annotate('6.09', xy=(4.20, 7.5))
plt.annotate('19.21', xy=(4.65, 21))
plt.annotate('48.41', xy=(4.9, 50))
plt.annotate('27.32', xy=(5.2, 29))
# Out:
# Text(5.2, 29, '27.32')
